# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
import time
import os

# %%
options = Options()
options.add_argument('--headless') 
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')
options.add_argument("window-size=1920,1080")
options.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 Chrome/121.0.0.0 Safari/537.36")

service = Service(executable_path=ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=options)

url = 'https://www.jobkorea.co.kr/Search/?stext=데이터분석'
driver.get(url)
time.sleep(5)

titles = []
companies = []
links = []
details = []


jobs = driver.find_elements(By.CSS_SELECTOR, 'article.list-item')

for job in jobs:
    try:
        a_tag = job.find_element(By.CSS_SELECTOR, 'a.information-title-link')
        title = a_tag.text.strip()
        href = a_tag.get_attribute('href')
        full_link = 'https://www.jobkorea.co.kr' + href if href.startswith('/') else href

        company = job.find_element(By.CSS_SELECTOR, 'div.list-section-corp').text.strip()

        detail_tags = job.find_elements(By.CSS_SELECTOR, 'ul.chip-information-group li.chip-information-item')
        detail_text = [d.text.strip() for d in detail_tags if d.text.strip()]

        titles.append(title)
        companies.append(company)
        links.append(full_link)
        details.append(detail_text)

    except Exception as e:
        print("오류 발생:", e)
        continue

driver.quit()

df = pd.DataFrame({
    'Site': ['Jobkorea'] * len(titles),
    'Col_Company': companies,
    'Col_Recruit': titles,
    'Col_detail': details,
    'Col_url': links
})


df.to_csv('data_tmp/data_jobkorea.csv', index=False, encoding='utf-8-sig')
print("Jobkorea 채용공고 저장 완료!")
display(df.head())
# Out:
# Jobkorea 채용공고 저장 완료!
#        Site    Col_Company                                       Col_Recruit  \
# 0  Jobkorea        더치트주식회사  데이터 애널리스트 / 데이터분석 전문가 / 통계 전문가 / Data Analyst (통
# 1  Jobkorea  넛지헬스케어㈜\n강소기업                       [캐시워크-병역특례] 데이터분석 담당 산업기능요원
# 2  Jobkorea       ㈜메디젠휴먼케어                           메디젠휴먼케어 데이터분석 담당 경력직 채용
# 3  Jobkorea  넛지헬스케어㈜\n강소기업                          [캐시워크] 데이터분석 담당 채용전환형 인턴
# 4  Jobkorea           한패스㈜           [한패스(주)/데이터분석팀] Google Analytics 데이터분석가
#
#                          Col_detail  \
# 0  [경력무관, 대졸↑, 정규직 외, 서울 구로구, D-24]
# 1   [경력무관, 학력무관, 병역특례, 서울 강남구, D-7]
# 2   [경력3년↑, 석사↑, 정규직, 서울 송파구, D-41]
# 3       [신입, 대졸↑, 인턴, 서울 강남구, D-10]
# 4      [경력, 학력무관, 정규직, 서울 성동구, D-6]
#
#                                              Col_url
# 0  https://www.jobkorea.co.kr/Recruit/GI_Read/466...
# 1  https://www.jobkorea.co.kr/Recruit/GI_Read/465...
# 2  https://www.jobkorea.co.kr/Recruit/GI_Read/465...
# 3  https://www.jobkorea.co.kr/Recruit/GI_Read/465...
# 4  https://www.jobkorea.co.kr/Recruit/GI_Read/465...
